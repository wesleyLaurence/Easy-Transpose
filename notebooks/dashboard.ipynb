# %% [markdown]
# # Easy-Transpose
# #### MySQL Dashboard

# %%
# import module
from easy_transpose import transpose

# %%
# initialize
t = transpose.Transpose()

# %%
t.connect()
# Out:
# User ID: wesley
# Password: ········

# %%
# calculate transposition
t.transpose('Piccolo','Bb4','Written')
# Out:
# 'Bb5'

# %%
# analytics dashboard
t.dashboard()

# %%
# get MySQL table
t.select_table('transpose')
# Out:
#             StartNote TransposeNote StartPosition    Instrument  \
# TransposeID
# 1                Cbb3          Gbb3       Concert   French Horn
# 2                Cbb3          Gbb3       Concert   French Horn
# 3                Cbb3          Gbb3       Concert   French Horn
# 4                  G3            G4       Concert        Guitar
# 5                  G3            A3       Concert    Bb Trumpet
# ...               ...           ...           ...           ...
# 75                 D3            F3       Concert    A Clarinet
# 76                 D2            A2       Concert  English Horn
# 77                Ab3           Db4       Concert    Alto Flute
# 78                 C2            C3       Concert        Guitar
# 79                 C2            C3       Concert        Guitar
#
#                   EventDateTime
# TransposeID
# 1           2020-05-03 23:23:32
# 2           2020-05-03 23:29:53
# 3           2020-05-03 23:38:11
# 4           2020-05-03 23:39:19
# ...
