# %%
# run app
! python app.py "C:\Users\wesle\Desktop\2020\Code\main\EasyTranspose\easy-transpose-master\scripts\app.py"

# %%
# show dashboard
from dashboard import Dashboard
d = Dashboard()
d.display()

# %%
# transpose SQL table
d.get_data()
# Out:
#             StartNote TransposeNote StartPosition             Instrument  \
# TransposeID
# 1                Cbb3          Gbb3       Concert            French Horn
# 2                Cbb3          Gbb3       Concert            French Horn
# 3                Cbb3          Gbb3       Concert            French Horn
# 4                  G3            G4       Concert                 Guitar
# 5                  G3            A3       Concert             Bb Trumpet
# 6                  G3            E3       Written             A Clarinet
# 7                  G3           Bb3       Concert             A Clarinet
# 8                  G3           Bb3       Concert             A Clarinet
# 9                 C#2           C#1       Written                 Guitar
# 10                C#2           C#1       Written                 Guitar
# 11                C#3           C#2       Written                 Guitar
# 12               Dbb4          Dbb5       Concert                 Guitar
# ...
